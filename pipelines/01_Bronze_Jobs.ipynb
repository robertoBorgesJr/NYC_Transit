# %%
# %run ./00_Config_Setup

# %%
# Notebook: 01_Bronze_Jobs
# MAGIC %run ./00_Config_Setup

# Ingestão Yellow
df_yellow_raw = spark.read.format("csv").option("header", True).load(path_yellow)
df_yellow_raw.write.format("delta").mode("overwrite").saveAsTable(f"{catalog}.{schema}.bronze_yellow")

# Ingestão FHV
df_fhv_raw = spark.read.format("csv").option("header", True).load(path_fhv)
df_fhv_raw.write.format("delta").mode("overwrite").saveAsTable(f"{catalog}.{schema}.bronze_fhv")
